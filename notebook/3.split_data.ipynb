# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import os
root_path = '../'
data_path = os.path.join(root_path, 'data')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys
sys.path.append('../')

from src.utils.model_selection import cv_splits
from src.plot.plot_streamflow import plot_cvs

# %%
target_site = '11238600'

# %%
station_info = pd.read_csv(
            os.path.join(
                data_path,
                'raw',
                'station_info.csv'
            )
        )
streamflow = pd.read_csv(
            os.path.join(
                data_path, 
                'raw', 
                'streamflow.csv'),
            parse_dates = ['DATE'],
            index_col='DATE'
           )

# %%
VAL_SIZE = .2

# %%
split_indices = cv_splits(streamflow, VAL_SIZE)

# %%
for train_idx, val_idx in split_indices:
    plot_cvs(streamflow, train_idx = train_idx, target_col=target_site, val_idx=val_idx)
